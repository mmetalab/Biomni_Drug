# %%
import pandas as pd

# %%
from biomni.agent import A1
# Out:
# None of PyTorch, TensorFlow >= 2.0, or Flax have been found. Models won't be available and only tokenizers, configuration and file/data utilities can be used.
# Loaded environment variables from .env

# %%
# Initialize the agent with data path, Data lake will be automatically downloaded on first run (~11GB)
# agent = A1(path='./data', llm='gemini-2.5-flash-live')
# Skip automatic datalake download (faster initialization)
agent = A1(path='./data', llm='gemini-2.5-flash-live', expected_data_lake_files = [])
# Out:
# 🎓 Academic mode: Using all datasets (including non-commercial)
#
# ...
# 🔧 BIOMNI CONFIGURATION
# ...
# 📋 DEFAULT CONFIG (Including Database LLM):
#   Path: ./data
#   Timeout Seconds: 600
#   Llm: claude-sonnet-4-5
#   Temperature: 0.7
#   Use Tool Retriever: True
#   Commercial Mode: Academic (all datasets)
#
# 🤖 AGENT LLM (Constructor Override):
#   LLM Model: gemini-2.5-flash-live
# ...
#
# Skipping datalake download (load_datalake=False)
# Note: Some tools may require datalake files to function properly.
# 📚 Loaded 2 know-how documents
# 📚 Loading 2 know-how documents into system prompt

# %%
from biomni.agent import A1

agent = A1(path='./data', llm='gemini-2.5-flash-live')
agent.launch_gradio_demo()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 4
#       1 from biomni.agent import A1
#       3 # agent = A1(path='./data', llm='gemini-2.5-flash-live')
# ----> 4 agent.launch_gradio_demo()
#
# File ~/Documents/GitHub/Biomni_Drug/biomni/agent/a1.py:2961, in A1.launch_gradio_demo(self, thread_id, share, server_name, require_verification)
#    2959 with gr.Row():
#    2960     with gr.Column(scale=1):
# -> 2961         main_chatbot = gr.Chatbot(
#    2962             label="Biomni A1 Agent",
#    2963             type="messages",
#    2964             height=800,
#    2965             show_copy_button=True,
#    2966             show_share_button=True,
#    2967         )
#    2968     with gr.Column(scale=1):
#    2969         innerloop_chatbot = gr.Chatbot(
#    2970             label="Biomni Executor",
#    2971             type="messages",
# ...
